# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, Dropout, BatchNormalization, Flatten, MaxPooling2D, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
# Download the weather images and put them in a directory

path = r'C:\Users\nickr\OneDrive\Documents\Nick Bootcamp\Machine Learning\Data Sets\Weather\Weather Dataset'
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
# This will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=12,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=12,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
# This is a CNN to categorize the weather images

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(0.5, seed = 5)(x)
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %%
# How many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 16,
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# C:\Users\nickr\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 79s 996ms/step - accuracy: 0.4834 - loss: 0.1386 - val_accuracy: 0.7037 - val_loss: 0.1147
# Epoch 2/16
#  1/75 ━━━━━━━━━━━━━━━━━━━━ 2:31 2s/step - accuracy: 0.6667 - loss: 0.1124
# C:\Users\nickr\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.6667 - loss: 0.1124 - val_accuracy: 0.7222 - val_loss: 0.0958
# Epoch 3/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.6854 - loss: 0.1010 - val_accuracy: 0.6574 - val_loss: 0.1297
# Epoch 4/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - accuracy: 0.7500 - loss: 0.1061 - val_accuracy: 0.6574 - val_loss: 0.1259
# Epoch 5/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7297 - loss: 0.0874 - val_accuracy: 0.5926 - val_loss: 0.1442
# Epoch 6/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.8333 - loss: 0.0452 - val_accuracy: 0.5741 - val_loss: 0.1523
# Epoch 7/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.7595 - loss: 0.0819 - val_accuracy: 0.7546 - val_loss: 0.0818
# Epoch 8/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.7500 - loss: 0.0561 - val_accuracy: 0.7269 - val_loss: 0.0922
# Epoch 9/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7541 - loss: 0.0798 - val_accuracy: 0.7361 - val_loss: 0.0942
# Epoch 10/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8333 - loss: 0.0521 - val_accuracy: 0.7500 - val_loss: 0.0854
# Epoch 11/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7900 - loss: 0.0739 - val_accuracy: 0.7083 - val_loss: 0.1005
# Epoch 12/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.9167 - loss: 0.0316 - val_accuracy: 0.7037 - val_loss: 0.1025
# Epoch 13/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.7986 - loss: 0.0705 - val_accuracy: 0.7917 - val_loss: 0.0729
# Epoch 14/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.7500 - loss: 0.0765 - val_accuracy: 0.7639 - val_loss: 0.0791
# Epoch 15/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.8337 - loss: 0.0588 - val_accuracy: 0.8241 - val_loss: 0.0622
# Epoch 16/16
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 110ms/step - accuracy: 0.9167 - loss: 0.0466 - val_accuracy: 0.8287 - val_loss: 0.0642

# %%
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss')
# Out:
# <Axes: title={'center': 'Model Loss'}>

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
# Out:
# <Axes: title={'center': 'Model Acurracy'}>

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 0.9166666865348816, Val_Accuracy: 0.8287037014961243
# Loss: 0.04661150649189949, Val_Loss: 0.06417253613471985

# %%
# Collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 16 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

# Confusion matrix for training data
cm = confusion_matrix(y_pred = [np.argmax(x) for x in y_predict], y_true = [np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 598ms/step

# %%
# This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 6) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
